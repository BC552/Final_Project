# %%
class admin:
    def __init__(self):
        self.foods_list = []
        self.admin_detail = []
        
    def sign_up(self,admin_name,admin_password):
        self.d = {'admin_name':admin_name,'admin_password':admin_password}
        self.admin_detail.append(self.d)
        
    def login_admin(self,admin_name,admin_password):
        if self.d['admin_name'] == admin_name and self.d['admin_password'] == admin_password:
            print('\n Admin login Successful \n')
        
        else:
            print('\n Something Error Occur \n')
        
        
    def add_items(self,id,name,quantity,price,discount,stock):
        self.dict = {'id':id,'name':name,'quantity':quantity,'price':price,'discount':discount,'stock':stock}
        self.foods_list.append(self.dict)
        return self.foods_list
        
        
    def view_items(self):
        return self.foods_list
        
    
    
    def edit_item_name(self,id,name):
        self.edit = self.foods_list[id-1]

        for i in self.edit:
            if i == 'name':
                self.edit[i]=name
        
        return self.foods_list
    
    def edit_item_quantity(self,id,quantity):
        self.edit = self.foods_list[id-1]

        for i in self.edit:
            if i == 'quantity':
                self.edit[i]=quantity
        
        return self.foods_list
    
    def edit_item_price(self,id,price):
        self.edit = self.foods_list[id-1]

        for i in self.edit:
            if i == 'price':
                self.edit[i]=price
        
        return self.foods_list
    
    def edit_item_discount(self,id,discount):
        self.edit = self.foods_list[id-1]

        for i in self.edit:
            if i == 'discount':
                self.edit[i]=discount
        
        return self.foods_list
    
    def edit_item_stock(self,id,stock):
        self.edit = self.foods_list[id-1]

        for i in self.edit:
            if i == 'stock':
                self.edit[i]=stock
        
        return self.foods_list
                
    def remove_items(self,id):  
        for e,i in enumerate(self.foods_list):
            for j,k in i.items():
                if j == 'id' and k == id:
                    self.foods_list.pop(e)
        
        return self.foods_list
                
 

class user:
    
    def __init__(self):
        self.user_data = []
        self.view_history = []
        
        
    def registration(self,full_name,phone_number,email,address,password):
        self.dict1 = {'Full Name':full_name,'Phone Number':phone_number,'Email':email,'Address':address,'Password':password}
        self.user_data.append(self.dict1)
        return '\n registration successful \n'
        
    def login(self,email,password):
        if self.dict1['Email']==email and self.dict1['Password']==password:
            return('\n Login successful \n')
            
        else:
            return('\n Something error....please check mail and password \n')
            
    
    def place_orders(self):
        
        self.visible_list = []     
        for index,lists in enumerate(a.foods_list):
            show_list = index+1,lists['name'],(lists['quantity']),['INR',lists['price']]
            self.visible_list.append(show_list)
        
        for i in self.visible_list:
            print(i,'\n')
            
    def select_orders(self,number):
        
        if len(self.visible_list)>number-1:   
            
            self.view_history.append(self.visible_list[number-1])
            
            return self.visible_list[number-1]
        else:
            return 'List out of range'
                
    def order_historys(self):        
        
        return 'Order history',self.view_history
        
        
    def update_profile_name(self,full_name):
        self.update = self.user_data[0]
        
        for i,j in self.update.items():
            if i == "Full Name":
                self.update[i] = full_name
        
        return self.user_data
    
    def update_profile_phone_number(self,phone_number):
        self.update = self.user_data[0]
        
        for i,j in self.update.items():
            if i == "Phone Number":
                self.update[i] = phone_number
        
        return self.user_data
    
    def update_profile_name(self,email):
        self.update = self.user_data[0]
        
        for i,j in self.update.items():
            if i == "Email":
                self.update[i] = email
        
        return self.user_data
    
    def update_profile_name(self,address):
        self.update = self.user_data[0]
        
        for i,j in self.update.items():
            if i == "Address":
                self.update[i] = address
        
        return self.user_data
    
    def update_profile_name(self,password):
        self.update = self.user_data[0]
        
        for i,j in self.update.items():
            if i == "Password":
                self.update[i] = password
        
        return self.user_data
                      


a = admin()

a.sign_up('foodie','foodieapp')
a.login_admin('foodie','foodieapp')

a.add_items(1,'Tandoori Chicken','4 pieces',240,10,30)
a.add_items(2,'Vegan Burger','1 pieces',320,10,40)
a.add_items(3,'Truffle Cake','500 gram',900,1,15)
a.add_items(4,'Chicken Burger','5 pieces',400,1,50)
print(a.view_items())        
        
        
                
            
u = user()
print(u.registration('abcdef',9457568645,'abcdef@gmail.com','address will be enter in future','abcdefpass'))

print(u.login('abcdef@gmail.com','abcdefpass'))

print(u.update_profile_phone_number(9988776655))



u.place_orders()



print(list(map(u.select_orders,[2,4])))
print(list(map(u.select_orders,[3])))
print(list(map(u.select_orders,[4,1])))

u.order_historys()
# Out:
#  Admin login Successful
#
# [{'id': 1, 'name': 'Tandoori Chicken', 'quantity': '4 pieces', 'price': 240, 'discount': 10, 'stock': 30}, {'id': 2, 'name': 'Vegan Burger', 'quantity': '1 pieces', 'price': 320, 'discount': 10, 'stock': 40}, {'id': 3, 'name': 'Truffle Cake', 'quantity': '500 gram', 'price': 900, 'discount': 1, 'stock': 15}, {'id': 4, 'name': 'Chicken Burger', 'quantity': '5 pieces', 'price': 400, 'discount': 1, 'stock': 50}]
#
#  registration successful
#
#
#  Login successful
#
# [{'Full Name': 'abcdef', 'Phone Number': 9988776655, 'Email': 'abcdef@gmail.com', 'Address': 'address will be enter in future', 'Password': 'abcdefpass'}]
# (1, 'Tandoori Chicken', '4 pieces', ['INR', 240])
#
# (2, 'Vegan Burger', '1 pieces', ['INR', 320])
#
# (3, 'Truffle Cake', '500 gram', ['INR', 900])
#
# (4, 'Chicken Burger', '5 pieces', ['INR', 400])
#
# [(2, 'Vegan Burger', '1 pieces', ['INR', 320]), (4, 'Chicken Burger', '5 pieces', ['INR', 400])]
# ...
